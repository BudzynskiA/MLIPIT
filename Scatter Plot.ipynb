# %%
import pandas as pd
df = pd.DataFrame({
    'Transport_Prices' : [1001, 500, 450, 300, 600, 700, 800, 400, 500, 400, 760, 460, 560, 360, 703, 400, 300, 
                          700, 400, 500, 300, 600, 400, 500],
    'Kilometers' : [1003, 508, 552, 330, 650, 600, 700, 300, 550, 360, 770, 420, 510, 310, 720, 430, 340, 
                          500, 460, 506, 306, 705, 405, 504],
    'Weight' : [20, 25, 3, 4, 1, 2, 15, 14, 13, 25, 25, 2, 15, 14, 13, 25, 25, 
                          15, 14, 13, 25, 25, 2, 15,],
    },)
df.plot.scatter(x='Transport_Prices',y='Kilometers', c='Weight', colormap='viridis')
# Out:
# <AxesSubplot:xlabel='Transport_Prices', ylabel='Kilometers'>
