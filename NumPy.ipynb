# %%
import numpy as np
Transport_Prices = [1000, 500, 300, 700, 400]
my_np_list = np.array(Transport_Prices)

print(type(Transport_Prices))
my_np_list
# Out:
# <class 'list'>
# array([1000,  500,  300,  700,  400])
