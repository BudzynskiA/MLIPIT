# %% [markdown]
# # Lesson 1 Basics
#
# ## There are two types of cells:
# - code
# - text

# %%
print("Hello, My name is ARCAP. I am a robot who has learned to predict the price of transporting goods. How can I help you?")
# Out:
# Hello, My name is ARCAP. I am a robot who has learned to predict the price of transporting goods. How can I help you?

# %%
Transport_Price = 1000

# %%
print(Transport_Price)
# Out:
# 1000

# %%
Cargo_Type = "steel"

# %%
print(Cargo_Type)
# Out:
# steel

# %%
type(Transport_Price)
# Out:
# int

# %%
type(Cargo_Type)
# Out:
# str

# %%
ADR = True
print(ADR)
type(ADR)
# Out:
# True
# bool

# %%
Transport_Prices = [1000, 500, 300, 700, 400]

print(Transport_Prices)
type(Transport_Prices)
# Out:
# [1000, 500, 300, 700, 400]
# list

# %%
Transport_Prices[4]
# Out:
# 400

# %%
Transport_Prices
# Out:
# [1000, 500, 300, 700, 400]

# %%
Transport_Prices[2:5] # we start with the third value (start_index = 2) and end with the fifth (which has index 4)
# Out:
# [300, 700, 400]

# %%
Copy_Transport_Prices = Transport_Prices
id(Copy_Transport_Prices), id(Transport_Prices)
# Out:
# (2315528194304, 2315528194304)

# %%
Copy_Transport_Prices[1] = 2000
Transport_Prices
# Out:
# [1000, 2000, 300, 700, 400]

# %%
Transport_Prices = [1000, 500, 300, 700, 400]
clone_Transport_Prices = Transport_Prices[:]
clone_Transport_Prices[0] = 5000

print(Transport_Prices)
id(Transport_Prices), id(clone_Transport_Prices[:])
# Out:
# [1000, 500, 300, 700, 400]
# (2315528193664, 2315528380608)

# %%
Unpaid_Transport_Prices = [1000, 500, 300, 700, 400]
print(Unpaid_Transport_Prices)
Unpaid_Transport_Prices.append(2500)
print(Unpaid_Transport_Prices)
# Out:
# [1000, 500, 300, 700, 400]
# [1000, 500, 300, 700, 400, 2500]

# %%
Transport_Prices = [1000, 500, 300, 700, 400]
print(Transport_Prices)
Transport_Prices.insert(2, 350)
print(Transport_Prices)
# Out:
# [1000, 500, 300, 700, 400]
# [1000, 500, 350, 300, 700, 400]

# %%
January_Transport_Prices = [1000, 500, 300, 700, 400]
February_Transport_Prices = [1500, 300, 500, 3300, 750, 840.50]
March_Transport_Prices = [1000, 500, 300, 740.5, 940, 1040]
FirstQuarter_Transport_Prices = January_Transport_Prices + February_Transport_Prices + March_Transport_Prices
print(FirstQuarter_Transport_Prices)
# Out:
# [1000, 500, 300, 700, 400, 1500, 300, 500, 3300, 750, 840.5, 1000, 500, 300, 740.5, 940, 1040]
