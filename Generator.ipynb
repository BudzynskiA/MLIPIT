# %%
Transport_Prices = [1000, 500, 300, 700, 400]
def Prices_with_Vat(Transport_Prices):
    for element in Transport_Prices: 
        yield element * 1.23

list( Prices_with_Vat(Transport_Prices) )
# Out:
# [1230.0, 615.0, 369.0, 861.0, 492.0]

# %%
dict( enumerate(['water','Frozen_Meat','Frozen_Fish','Butter','Fertilizers']) )
# Out:
# {0: 'water', 1: 'Frozen_Meat', 2: 'Frozen_Fish', 3: 'Butter', 4: 'Fertilizers'}
