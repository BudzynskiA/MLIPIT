# %%
List_Transport_Prices = [1000, 500, 300, 700, 400]

for element in List_Transport_Prices:
    print(element)
# Out:
# 1000
# 500
# 300
# 700
# 400

# %%
List_Transport_Prices = [1000, 500, 300, 700, 400]

List_Transport_Prices_withVat = []
for element in List_Transport_Prices:
    Element_withVat = element * 1.23
    List_Transport_Prices_withVat.append(Element_withVat)
    
List_Transport_Prices_withVat
# Out:
# [1230.0, 615.0, 369.0, 861.0, 492.0]

# %%
List_Transport_Prices_withVat = [element * 1.23 for element in List_Transport_Prices]
List_Transport_Prices_withVat
# Out:
# [1230.0, 615.0, 369.0, 861.0, 492.0]
