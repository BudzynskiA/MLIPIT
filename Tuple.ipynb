# %%
Tuple_Transport_Prices = (1000, 500, 300, 700, 400)
print(Tuple_Transport_Prices)
type(Tuple_Transport_Prices)
# Out:
# (1000, 500, 300, 700, 400)
# tuple

# %%
Tuple_Transport_Prices[0]
# Out:
# 1000

# %%
Tuple_Transport_Prices = 1000, 500, 300, 700, 400 
print(Tuple_Transport_Prices)
# Out:
# (1000, 500, 300, 700, 400)
