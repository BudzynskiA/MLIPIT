# %%
import pandas as pd
df = pd.DataFrame({
    'Transport_Prices' : [1000, 500, 550, 300, 600, 700, 800, 400, 500, 300, 700, 400, 500, 300, 700, 400, 300, 
                          700, 400, 500, 300, 700, 400, 500]
    },)
hist = df.hist(bins=7)
