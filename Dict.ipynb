# %%
dict_Used_Fuel_October_2021 = {
    'Volvo FH 460': 3543,
    'Scania R 560': 1390,
    'Volvo FH 500KM': 4300,
    'Renault Premium 460KM': 2343,
    'DAF XF 105 460 EEV': 1987,
    'Scania R450' : 490,
    'VOLVO FH 500' : 1840,
}
print(dict_Used_Fuel_October_2021)
type(dict_Used_Fuel_October_2021)
# Out:
# {'Volvo FH 460': 3543, 'Scania R 560': 1390, 'Volvo FH 500KM': 4300, 'Renault Premium 460KM': 2343, 'DAF XF 105 460 EEV': 1987, 'Scania R450': 490, 'VOLVO FH 500': 1840}
# dict

# %%
dict_Used_Fuel_October_2021['DAF XF 105 460 EEV']
# Out:
# 1987

# %%
if 'Volvo FH 460' in dict_Used_Fuel_October_2021:
    print('Volvo FH 460 is in dict')
else:
    print('Volvo FH 460 is not in dict')
    
if 'VOLVO FH12 380' in dict_Used_Fuel_October_2021:
    print('VOLVO FH12 380 is in dict')
else:
    print('VOLVO FH12 380 is not in dict')
# Out:
# Volvo FH 460 is in dict
# VOLVO FH12 380 is not in dict
