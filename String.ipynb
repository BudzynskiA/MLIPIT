# %%
Cargo_Type = 'Steel'
print(Cargo_Type)
type(Cargo_Type)
# Out:
# Steel
# str

# %%
Cargo_Type[0]
# Out:
# 'S'

# %%
Cargo_Type[-1]
# Out:
# 'l'

# %%
"The average price for transport in October " + str(2021) + " was " + str(540) + " €"
# Out:
# 'The average price for transport in October 2021 was 540 €'

# %%
"The average price for transport in October {0} was {1} €".format(2021, 540)
# Out:
# 'The average price for transport in October 2021 was 540 €'
