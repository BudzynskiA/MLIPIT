# %%
def identity(price):
    return price

identity(1050)
# Out:
# 1050

# %%
def is_even(number):
    if number > 0.8:
        return "Good price"
    else:
        return 'Too low price'
    
is_even(0.79)
# Out:
# 'Too low price'

# %%
List_Transport_Prices = [1000, 500, 300, 700, 400]
def even (List_Transport_Prices):
    return [value_List_Transport_Prices >500 for value_List_Transport_Prices in List_Transport_Prices]
even(List_Transport_Prices)
# Out:
# [True, False, False, True, False]

# %%
my_map(lambda x: x >500, [1000, 500, 300, 700, 400])
# Out:
# [True, False, False, True, False]
